# %% [markdown]
# # Week 4: Introduction to CNNs in Keras
#
# For comparison, we're going to use the same MNIST Handwritten Digit Dataset as last week, to see whether we can
# find a better model using a CNN.
#
# The first 6 models show how to create a simple CNN (the same basic design as was presented in the lesson, but
# with realistic layer widths) and how to add various potential improvements. The last 5 models are examples
# of deep CNNs for optimal performance.
#
# 1. Simple CNN with 2 convolution layers and 2 dense layers
# 2. Simple CNN with ReduceLRonPlateau
# 3. Simple CNN with Exponential Decay
# 4. Simple CNN with Cosine Decay
# 5. Simple CNN plus Batch Norm and Dropout
# 6. Simple CNN plus L2 Normalization
# 7. VGG-16 with five pooling blocks and Global Average Pooling
# 8. VGG-16 with Flatten instead of GAP
# 9. VGG-16 with Dropout
# 10. Deep CNN with Batch Norm and Dropout
# 11. Deep CNN with Data Augmentation

# %% [markdown]
# ## 1. Setup and Data Loading
# Import necessary libraries and preprocess the MNIST dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time


import tensorflow as tf
from tensorflow.keras import layers, Input, models, callbacks, regularizers
from tensorflow.keras.callbacks import Callback,EarlyStopping,ReduceLROnPlateau,LearningRateScheduler
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam,AdamW
from tensorflow.keras.optimizers.schedules import CosineDecay, ExponentialDecay

from tensorflow.keras.layers import Conv2D,BatchNormalization,Activation,MaxPooling2D,Dropout,GlobalAveragePooling2D,Dense,Flatten


# utility code

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))


'''  How to time your code
# start timer
start = time.time()

<your code here> 

# Record end time and print execution time
end = time.time()
print(f"Execution Time: " + format_hms(end-start))
'''

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppresses INFO and WARNING messages

notebook_start = time.time()

# %%
# Utility to print learning curves

results = {}

def plot_learning_curves(hist, 
                         title="Learning Curves", 
                         best_epoch=None,              # None = print absolute minimum val_loss point on both plots
                                                       # else assume is 0-based early stopping trigger point
                         verbose=True
                        ):

    val_losses = hist.history['val_loss']
    
    if best_epoch:
        min_val_epoch = best_epoch
    else:
        min_val_epoch = val_losses.index(min(val_losses))
        
    val_loss_at_min_loss = hist.history['val_loss'][min_val_epoch]    
    val_acc_at_min_loss = hist.history['val_accuracy'][min_val_epoch]
    

    n_epochs = len(val_losses)
    epochs = list(range(1, n_epochs + 1))

    # Determine tick interval and xticks starting from 0

    tick_interval = max(1, n_epochs // 20)
    xticks = list(range(0, n_epochs + 1, tick_interval))

    plt.figure(figsize=(8, 8))

    # --- Loss Plot ---
    plt.subplot(2, 1, 1)
    plt.plot(epochs, hist.history['loss'], label='Train Loss')
    plt.plot(epochs, hist.history['val_loss'], label='Val Loss')
    plt.scatter(min_val_epoch + 1, val_loss_at_min_loss, color='red', marker='x', s=50, label='Min Val Loss') 
    plt.title(f'{title} - Loss')
    plt.ylabel('Loss')
    plt.xticks(xticks)
    plt.legend()
    plt.grid(True)

    # --- Accuracy Plot ---
    plt.subplot(2, 1, 2)
    plt.plot(epochs, hist.history['accuracy'], label='Train Accuracy')
    plt.plot(epochs, hist.history['val_accuracy'], label='Val Accuracy')
    plt.scatter(min_val_epoch + 1, val_acc_at_min_loss, color='red', marker='x', s=50, label='Acc @ Min Val Loss')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    # plt.ylim(0, 1.05)
    plt.xticks(xticks)
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    if verbose:
        print(f"Final Training Loss:            {hist.history['loss'][-1]:.4f}")
        print(f"Final Training Accuracy:        {hist.history['accuracy'][-1]:.4f}")
        print(f"Final Validation Loss:          {hist.history['val_loss'][-1]:.4f}")
        print(f"Final Validation Accuracy:      {hist.history['val_accuracy'][-1]:.4f}")
        print(f"Minimum Validation Loss:        {val_loss_at_min_loss:.4f} (Epoch {min_val_epoch + 1})")
        print(f"Validation Accuracy @ Min Loss: {val_acc_at_min_loss:.4f}")

    results[title] = (val_acc_at_min_loss, min_val_epoch + 1)

# %% [markdown]
# #### The MNIST Dataset
#
# Let's load the dataset just as we did last time.

# %%
# Load and preprocess MNIST
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.reshape(-1,28,28,1).astype('float32')/255.0
X_test = X_test.reshape(-1,28,28,1).astype('float32')/255.0
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %% [markdown]
# ###  Wrapper for training and testing
#
# #### Assumptions:
# - Early stopping is default, add other callbacks as needed
# - `X_train,y_train,X_test,y_test` already defined, accessed here as global variables

# %%
# Globals

global_epochs = 200
global_batch_size = 256
global_learning_rate = 0.0001

# Needed by LR schedulers

steps_per_epoch = int(np.ceil(len(X_train) / global_batch_size))
total_steps = global_epochs * steps_per_epoch

# Store results of runs by title

# %%
def train_and_test(model, 
                   epochs        = global_epochs,                 # Just needs to be bigger than early stop point
                   lr_schedule   = global_learning_rate,                 # Default for Adam / 10. Seems to work well in general on this task. 
                   optimizer     = "Adam",
                   title         = "Learning Curves",
                   batch_size    = global_batch_size, 
                   use_early_stopping = True,
                   patience      = 10,                     # To turn off early stopping, set patience to same as epochs
                   min_delta     = 0.001,                 # We only look at first 4 digits after decimal point
                   callbacks     = [],                     # for extra callbacks other than early stopping
                   verbose       = 0,
                   return_history = False
                  ):

    print(f"{title}:  ",end='')
    # If parameters are not at defaults given above, print them out

    if lr_schedule != global_learning_rate:
        print(f'lr_schedule: {lr_schedule}', end='')
    if batch_size != global_batch_size:
        print(f'\tbatch_size: {batch_size}', end='')
    if patience != 10:
        print(f'\tpatience: {patience}', end='')
    if min_delta != 0.001:
        print(f'\tmin_delta: {min_delta}', end='')
    if callbacks != []:
        print(f'\tcallbacks: {callbacks}', end='')
    print('\n')

    if optimizer == "Adam":
        opt = Adam(learning_rate=lr_schedule) 
    else:
        opt = optimizer
    
    #Compiling the model
    model.compile(optimizer=opt, 
                  loss="categorical_crossentropy", 
                  metrics=["accuracy"]
                 )

    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=patience,
        min_delta=min_delta,
        restore_best_weights=True,
        verbose=verbose
    )
    

    if use_early_stopping:
        cbs=[early_stop] + callbacks
    else:
        cbs=callbacks

    # start timer
    start = time.time()
    
    # Fit the model with early stopping
    history = model.fit(X_train, y_train,
                        epochs=global_epochs,
                        batch_size=batch_size,
                        validation_split=0.2,
                        callbacks=cbs,
                        verbose=verbose
                       )

    best_epoch = early_stop.best_epoch
    best_acc    = history.history['val_accuracy'][best_epoch]

    
    # Plot training history
    plot_learning_curves(history, title=title, best_epoch = best_epoch)

    # Evaluate on test data
    test_loss, test_accuracy = model.evaluate(X_test, y_test,verbose=verbose)
    
    print(f"\nTest Accuracy: {test_accuracy:.4f}")
    print(f"Test Loss: {test_loss:.4f}")

    print(f"\nValidation-Test Gap (accuracy): {abs(best_acc - test_accuracy):.6f}")
    
    # Record end time and print execution time
    end = time.time()
    print(f"\nExecution Time: " + format_hms(end-start))

    if return_history:
        return history

# %% [markdown]
# #### Callbacks (inputs to fit)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-4,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-7,           # Lower bound on the learning rate.
    verbose=0,             # 0: quiet, 1: update messages.
)

# %% [markdown]
# #### Learning Rate Schedulers (input to optimizer Adam)

# %%
exp_decay = ExponentialDecay(
    initial_learning_rate=0.0001,  #  the starting learning rate (before any decay)
    decay_steps=total_steps,     #  how many training steps (batches) before applying decay
    decay_rate=0.98,              #  multiplicative factor of decay (new_lr = lr * decay_rate^(step/decay_steps))
    staircase=False,             #  if True, decay in discrete intervals (floor(step/decay_steps)),
                                 #  if False, decay smoothly each step
)

cosine_decay = CosineDecay(
    initial_learning_rate=0.0001, #  the starting learning rate
    decay_steps=total_steps,      #  number of training steps (batches) over which to decay
    alpha=0.0,                    #  minimum learning rate value as a fraction of initial_learning_rate
                                  #  (final_lr = initial_lr * alpha)
)

# %% [markdown]
# ### 1. Simple CNN model
#
# We start with the simplest CNN model, based on the "expanding CNN layer" strategy (32 -> 64).

# %%
tiny_cnn = models.Sequential(
    [
        Input((28,28,3)),  
        Conv2D(3, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(4, (3, 3), activation='relu'),              
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(16, activation='relu'),
        Dense(10, activation='softmax')
    ],
    name = "Tiny_CNN"
)

tiny_cnn.summary()
# Out:
# Model: "Tiny_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)              │ (None, 26, 26, 3)      │            84 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 13, 13, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 11, 11, 4)      │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 5, 5, 4)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 16)             │         1,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,982 (7.74 KB)
#  Trainable params: 1,982 (7.74 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_simple1 = models.Sequential([
    Input(shape=X_train.shape[1:]),  
    Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal'),              
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu', kernel_initializer='he_normal'),
    Dense(10, activation='softmax')  # 10 output classes for digits 0-9
    


train_and_test(model_simple1,epochs=global_epochs,title="Simple CNN")
# Out:
# Simple CNN:
# Final Training Loss:            0.0327
# Final Training Accuracy:        0.9893
# Final Validation Loss:          0.0822
# Final Validation Accuracy:      0.9819
# Minimum Validation Loss:        0.0574 (Epoch 19)
# Validation Accuracy @ Min Loss: 0.9843
#
# Test Accuracy: 0.9866
# Test Loss: 0.0426
#
# Validation-Test Gap (accuracy): 0.002267
#
# Execution Time: 00:02:08

# %% [markdown]
# ### 2. Simple CNN with ReduceLROnPlateau
#
# ### 2. Simple CNN with ReduceLROnPlateau
#
# Top 5 Results of grid search:
#
#     (0.987500011920929, 34) (0.3, 7, 0.001)
#     (0.9871666431427002, 27) (0.3, 5, 1e-05)
#     (0.9871666431427002, 35) (0.4, 7, 1e-05)
#     (0.9869999885559082, 26) (0.4, 5, 1e-05)
#     (0.9869999885559082, 27) (0.7, 5, 0.001)

# %%
model_simple2 = models.Sequential([
    Input(shape=X_train.shape[1:]),  
    Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal'),              # The "expanding CNN layer" (32 -> 64) design is common
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu', kernel_initializer='he_normal'),
    Dense(10, activation='softmax')  # 10 output classes for digits 0-9
])


reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.3,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=7,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=0.001,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=0,             # 0: quiet, 1: update messages.
)


train_and_test(model_simple2,epochs=global_epochs,title="Simple CNN + ReduceLROnPlateau",callbacks=[reduce_lr])
# Out:
# Simple CNN + ReduceLROnPlateau:  	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x387c21cf0>]
# Final Training Loss:            0.0215
# Final Training Accuracy:        0.9939
# Final Validation Loss:          0.0543
# Final Validation Accuracy:      0.9847
# Minimum Validation Loss:        0.0536 (Epoch 24)
# Validation Accuracy @ Min Loss: 0.9848
#
# Test Accuracy: 0.9870
# Test Loss: 0.0430
#
# Validation-Test Gap (accuracy): 0.002167
#
# Execution Time: 00:02:29

# %% [markdown]
# ### 3. Simple CNN with Exponential Decay
#
# Top 5 results of grid search for initial_learning_rate, epochs, decay_rate:
#
#     (0.9863333106040955, 24) (0.0001, 120, 0.95)
#     (0.9862499833106995, 22) (0.0001, 30, 0.95)
#     (0.9859166741371155, 20) (0.0001, 70, 0.95)
#     (0.9859166741371155, 108) (1e-05, 120, 0.95)
#     (0.9857500195503235, 5) (0.001, 120, 0.95)

# %%
model_simple3 = models.Sequential([
    Input(shape=X_train.shape[1:]),  
    Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal'),              # The "expanding CNN layer" (32 -> 64) design is common
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu', kernel_initializer='he_normal'),
    Dense(10, activation='softmax')  # 10 output classes for digits 0-9
])


temp_epochs = 120
temp_total_steps = temp_epochs * steps_per_epoch


exp_decay = ExponentialDecay(
    initial_learning_rate=0.0001, # ─ the starting learning rate (before any decay)
    decay_steps=temp_total_steps,       # ─ how many training steps (batches) before applying decay
    decay_rate=.95,                # ─ multiplicative factor of decay (new_lr = lr * decay_rate^(step/decay_steps))
    staircase=False,               # ─ if True, decay in discrete intervals (floor(step/decay_steps)),
                                   #   if False, decay smoothly each step
)


train_and_test(model_simple3,epochs=temp_epochs,lr_schedule=exp_decay,title="Simple CNN + Exponential Decay")
# Out:
# Simple CNN + Exponential Decay:  lr_schedule: <keras.src.optimizers.schedules.learning_rate_schedule.ExponentialDecay object at 0x387c4b5b0>
# Final Training Loss:            0.0207
# Final Training Accuracy:        0.9934
# Final Validation Loss:          0.0523
# Final Validation Accuracy:      0.9861
# Minimum Validation Loss:        0.0510 (Epoch 18)
# Validation Accuracy @ Min Loss: 0.9857
#
# Test Accuracy: 0.9868
# Test Loss: 0.0411
#
# Validation-Test Gap (accuracy): 0.001133
#
# Execution Time: 00:02:03

# %% [markdown]
# ### 4. Simple CNN with Cosine Decay

# %%
model_simple4 = models.Sequential([
    Input(shape=X_train.shape[1:]),  
    Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal'),              # The "expanding CNN layer" (32 -> 64) design is common
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu', kernel_initializer='he_normal'),
    Dense(10, activation='softmax')  # 10 output classes for digits 0-9
])


epochs          = 20
initial_lr      = 1e-2          # MNIST converges faster with 0.005–0.02

steps_per_epoch = len(X_train) // global_batch_size
total_steps     = epochs * steps_per_epoch

cosine_lr = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate = initial_lr,
    decay_steps           = total_steps,
    alpha                 = 0.1,          # keep 10 % of the start LR
    warmup_steps=5 * steps_per_epoch,   # 5 warm‑up epochs
    warmup_target=initial_lr/2
)


train_and_test(model_simple4,epochs=epochs,lr_schedule=cosine_decay,title="Simple CNN + Cosine Decay")
# Out:
# Simple CNN + Cosine Decay:  lr_schedule: <keras.src.optimizers.schedules.learning_rate_schedule.CosineDecay object at 0x12138ffa0>
# Final Training Loss:            0.0283
# Final Training Accuracy:        0.9909
# Final Validation Loss:          0.0615
# Final Validation Accuracy:      0.9843
# Minimum Validation Loss:        0.0534 (Epoch 19)
# Validation Accuracy @ Min Loss: 0.9833
#
# Test Accuracy: 0.9850
# Test Loss: 0.0474
#
# Validation-Test Gap (accuracy): 0.001667
#
# Execution Time: 00:01:51

# %% [markdown]
# ### 5. Simple CNN plus Batch Normalization and Dropout in the dense layer
#
# Results for different dropout rates:
#
#     (0.9904166460037231, 35) Simple CNN + Batch Norm and Dropout: 0.4
#     (0.9903333187103271, 29) Simple CNN + Batch Norm and Dropout: 0.5
#     (0.9898333549499512, 29) Simple CNN + Batch Norm and Dropout: 0.6
#     (0.9891666769981384, 37) Simple CNN + Batch Norm and Dropout: 0.2
#     (0.9891666769981384, 26) Simple CNN + Batch Norm and Dropout: 0.3
#     (0.9890833497047424, 33) Simple CNN + Batch Norm and Dropout: 0.1
#
# Notes:
# - Since batch normalization shifts the activations, we'll do the activation function **after** batch normalization. This follows the usual pattern:
#
# > Conv/Dense → BatchNorm → ReLU → (Dropout/Pooling)
#
# - Modest improvement with reduce on plateau and cosine decay.

# %%
model_simple5 = models.Sequential([
    Input(shape=X_train.shape[1:]),
    Conv2D(32, (3, 3), activation=None, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation=None, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(64, activation=None, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.4),

    Dense(10, activation='softmax')
])



train_and_test(model_simple5,title="Simple CNN + Batch Norm and Dropout")
# Out:
# Simple CNN + Batch Norm and Dropout:
# Final Training Loss:            0.0215
# Final Training Accuracy:        0.9941
# Final Validation Loss:          0.0365
# Final Validation Accuracy:      0.9899
# Minimum Validation Loss:        0.0364 (Epoch 22)
# Validation Accuracy @ Min Loss: 0.9891
#
# Test Accuracy: 0.9892
# Test Loss: 0.0320
#
# Validation-Test Gap (accuracy): 0.000117
#
# Execution Time: 00:03:17

# %% [markdown]
# ### 6. Simple CNN plus L2 Normalization
#
# Top 5 results. All over the place!
#
#
#     (0.9860000014305115, 45) Simple CNN + L2 Normalization: 0.001
#     (0.9855833053588867, 26) Simple CNN + L2 Normalization: 1e-06
#     (0.984000027179718, 17) Simple CNN + L2 Normalization: 0.0001
#     (0.9817500114440918, 15) Simple CNN + L2 Normalization: 1e-05
#     (0.971833348274231, 30) Simple CNN + L2 Normalization: 0.01

# %%
weight_decay = 0.001

model_simple6 = models.Sequential([
    Input(shape=X_train.shape[1:]),

    Conv2D(32, (3, 3), activation='relu',
                  kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(weight_decay)),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation='relu',
                  kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(weight_decay)),
    MaxPooling2D((2, 2)),

    Flatten(),

    Dense(64, activation='relu',
                 kernel_initializer='he_normal',
                 kernel_regularizer=regularizers.l2(weight_decay)),

    Dense(10, activation='softmax')
])



train_and_test(model_simple6,epochs=global_epochs,title=f"Simple CNN + L2 Normalization")
# Out:
# Simple CNN + L2 Normalization:
# Final Training Loss:            0.1473
# Final Training Accuracy:        0.9888
# Final Validation Loss:          0.1639
# Final Validation Accuracy:      0.9848
# Minimum Validation Loss:        0.1612 (Epoch 40)
# Validation Accuracy @ Min Loss: 0.9853
#
# Test Accuracy: 0.9867
# Test Loss: 0.1521
#
# Validation-Test Gap (accuracy): 0.001367
#
# Execution Time: 00:03:24

# %% [markdown]
# ### 7. VGG-16
#
# This well-known model uses four pooling blocks and a very large classification head. It also uses `GlobalAveragePooling`, which is characteristic of advanced CNNs designs.
#
# #### What does `GlobalAveragePooling2d()` do?
#
# You will see either `layer.flatten()` or `layer.GlobalAveragePooling2D()` to make the transition between convolutional layers and the dense head. The latter possibility is
# commonly used in CNNs and it is important to know why.
#
# **Flatten vs GlobalAveragePooling2D**
#
# Both `Flatten()` and `GlobalAveragePooling2D()` are used to convert the 3D output of convolutional layers into a 1D vector that can be passed to a `Dense` layer — but they do it in very different ways:
#
# - **`Flatten()`** unrolls all the pixels from all feature maps into a single long vector.
#   - Keeps all spatial detail
#   - Results in many more parameters when followed by a `Dense` layer
#   - **Example:** a `11×11×4` feature map becomes a 484-element vector
#
# ![Screenshot 2025-07-14 at 11.54.36 AM.png](attachment:df07e1eb-9f76-4b7e-9677-4a5995de86dc.png)
#
# - **`GlobalAveragePooling2D()`** averages each feature map into a single number.
#   - Reduces spatial dimensions (H × W) by computing the mean of each feature map
#   - Produces far fewer parameters and encourages generalization
#   - **Example:** a `11x11x4` feature map becomes a 4-element vector:
#
#
# ![Screenshot 2025-07-14 at 11.54.42 AM.png](attachment:e263e923-f728-4595-8dfd-da492c1193fe.png)
#
# **Intuition**
#
# *Use `Flatten()` when you want the dense layer to learn from every individual spatial location in every feature map.*
# *Use `GlobalAveragePooling2D()` when you only care about how strongly each feature is activated overall, not where it occurs.*
#
# **In summary:**
# `Flatten()` retains all spatial information but can overfit due to high parameter count.
# `GlobalAveragePooling2D()` discards spatial layout but simplifies the model and often performs better in practice — especially in modern CNNs.
#
# Notes:
# - Got improvement with plateau and especially with cosine decay

# %%
model_vgg_16 = models.Sequential([
    Input((28,28,1)),
    # Block 1
    Conv2D(64,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(64,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 2
    Conv2D(128,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(128,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 3
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 4
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    GlobalAveragePooling2D(),

    Dense(4096, activation='relu', kernel_initializer='he_normal'),
    Dense(1024, activation='relu', kernel_initializer='he_normal'),
    Dense(256, activation='relu', kernel_initializer='he_normal'),
    Dense(10, activation='softmax'),
])


train_and_test(model_vgg_16,epochs=global_epochs,lr_schedule=0.00001,title="VGG-style Large")
# Out:
# VGG-style Large:  lr_schedule: 1e-05
# Final Training Loss:            0.0037
# Final Training Accuracy:        0.9988
# Final Validation Loss:          0.0512
# Final Validation Accuracy:      0.9896
# Minimum Validation Loss:        0.0462 (Epoch 18)
# Validation Accuracy @ Min Loss: 0.9894
#
# Test Accuracy: 0.9906
# Test Loss: 0.0325
#
# Validation-Test Gap (accuracy): 0.001183
#
# Execution Time: 00:11:05

# %% [markdown]
# ### 8. VGG-16 with Flatten

# %%
model_vgg_16 = models.Sequential([
    Input((28,28,1)),
    # Block 1
    Conv2D(64,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(64,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 2
    Conv2D(128,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(128,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 3
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 4
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    Flatten(), 

    Dense(4096, activation='relu', kernel_initializer='he_normal'),
    Dense(1024, activation='relu', kernel_initializer='he_normal'),
    Dense(256, activation='relu', kernel_initializer='he_normal'),
    Dense(10, activation='softmax'),
])


train_and_test(model_vgg_16,epochs=global_epochs,lr_schedule=0.00001,title="VGG-style Large with Flatten")
# Out:
# VGG-style Large with Flatten:  lr_schedule: 1e-05
# Final Training Loss:            0.0054
# Final Training Accuracy:        0.9981
# Final Validation Loss:          0.0532
# Final Validation Accuracy:      0.9883
# Minimum Validation Loss:        0.0485 (Epoch 11)
# Validation Accuracy @ Min Loss: 0.9868
#
# Test Accuracy: 0.9893
# Test Loss: 0.0340
#
# Validation-Test Gap (accuracy): 0.002550
#
# Execution Time: 00:08:14

# %% [markdown]
# ### 9. VGG-16 with Dropout

# %%
model_vgg_16 = models.Sequential([
    Input((28,28,1)),
    # Block 1
    Conv2D(64,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(64,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 2
    Conv2D(128,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(128,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 3
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(256,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    # Block 4
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    Conv2D(512,3, padding='same', activation='relu', kernel_initializer='he_normal'),
    MaxPooling2D(),

    GlobalAveragePooling2D(),

    Dense(4096, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    Dense(1024, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.4),
    Dense(256, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.3),
    Dense(10, activation='softmax'),
])


train_and_test(model_vgg_16,epochs=global_epochs,lr_schedule=0.00001,title="VGG-style Large with Dropout")
# Out:
# VGG-style Large with Dropout:  lr_schedule: 1e-05
# Final Training Loss:            0.0034
# Final Training Accuracy:        0.9993
# Final Validation Loss:          0.0481
# Final Validation Accuracy:      0.9879
# Minimum Validation Loss:        0.0340 (Epoch 24)
# Validation Accuracy @ Min Loss: 0.9904
#
# Test Accuracy: 0.9911
# Test Loss: 0.0283
#
# Validation-Test Gap (accuracy): 0.000683
#
# Execution Time: 00:15:14

# %% [markdown]
# ### 10. Deep CNN
#
# This is from a Medium post:
#
# https://medium.com/@BrendanArtley/mnist-keras-simple-cnn-99-6-731b624aee7f
#
# The author specified a block oriented design with Batch Norm and Dropout
# and a head consisting of 3 dense layers 512 -> 1024 -> 10.
#
# He did not do activation after batch norm, so we changed that to fit current best practices.
#
# We use the learning rate scheduler from his post.
#
# Notes:
# - Got improvement with exp and cosine decay

# %%
model_deep = models.Sequential([
    Input(shape=(28, 28, 1)),

    # Block 1
    Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Block 2
    Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Fully connected layers
    Flatten(),
    Dense(512, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(1024, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output layer
    Dense(10, activation='softmax')               # default initializer is best for softmax
])

#Define LearningRateScheduler
reduce_lr2 = LearningRateScheduler(lambda x: 1e-3 * 0.9 ** x)

train_and_test(model_deep,
               epochs=global_epochs,
               optimizer = Adam( learning_rate=0.00001, beta_1=0.9, beta_2=0.999 ),
               patience      = 10,                   
               min_delta     = 0.001,
               callbacks=[reduce_lr2],
               title="Deep CNN"
              )
# Out:
# Deep CNN:  	callbacks: [<keras.src.callbacks.learning_rate_scheduler.LearningRateScheduler object at 0x36ed2ba30>]
# Final Training Loss:            0.0042
# Final Training Accuracy:        0.9987
# Final Validation Loss:          0.0218
# Final Validation Accuracy:      0.9952
# Minimum Validation Loss:        0.0198 (Epoch 16)
# Validation Accuracy @ Min Loss: 0.9943
#
# Test Accuracy: 0.9948
# Test Loss: 0.0155
#
# Validation-Test Gap (accuracy): 0.000467
#
# Execution Time: 00:04:32

# %%
model_deep_gap = models.Sequential([
    Input(shape=(28, 28, 1)),

    # Block 1
    Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Block 2
    Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Fully connected layers
    GlobalAveragePooling2D(),
    
    Dense(512, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(1024, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output layer
    Dense(10, activation='softmax')               # default initializer is best for softmax
])

#Define LearningRateScheduler
reduce_lr2 = LearningRateScheduler(lambda x: 1e-3 * 0.9 ** x)

train_and_test(model_deep_gap,
               epochs=global_epochs,
               optimizer = Adam( learning_rate=0.00001, beta_1=0.9, beta_2=0.999 ),
               patience      = 10,                   
               min_delta     = 0.001,
               callbacks=[reduce_lr2],
               title="Deep CNN & GAP"
              )
# Out:
# Deep CNN & GAP:  	batch_size: 128	callbacks: [<keras.src.callbacks.learning_rate_scheduler.LearningRateScheduler object at 0x5a89de6b0>]
# Final Training Loss:            0.0167
# Final Training Accuracy:        0.9948
# Final Validation Loss:          0.0219
# Final Validation Accuracy:      0.9939
# Minimum Validation Loss:        0.0199 (Epoch 28)
# Validation Accuracy @ Min Loss: 0.9942
#
# Test Accuracy: 0.9936
# Test Loss: 0.0158
#
# Validation-Test Gap (accuracy): 0.000650
#
# Execution Time: 00:06:58

# %% [markdown]
# ### Another Medium Network
#
# This one from:
#
# https://medium.com/data-science/going-beyond-99-mnist-handwritten-digits-recognition-cfff96337392
#
# I added `kernel_initializer='he_normal'` and `SpacialDropout2D` in place of `Dropout`.

# %% [markdown]
# After improvements suggested by chatGPT, then added another conv block
#
# THis is the current best model.

# %%
from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(0.0005),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(0.0005),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

        # --- Convolutional Block 3 ---                         # This was added to original design
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(0.0005),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()
    
    Dense(128, use_bias=False, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x5a8900190>]
#
# Epoch 1/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.1578 - loss: 2.7330 - val_accuracy: 0.3142 - val_loss: 2.1399 - learning_rate: 1.0000e-04
# Epoch 2/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.3503 - loss: 2.0505 - val_accuracy: 0.6529 - val_loss: 1.4040 - learning_rate: 1.0000e-04
# Epoch 3/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.5745 - loss: 1.5061 - val_accuracy: 0.8606 - val_loss: 0.8848 - learning_rate: 1.0000e-04
# Epoch 4/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.7389 - loss: 1.1167 - val_accuracy: 0.9114 - val_loss: 0.6583 - learning_rate: 1.0000e-04
# Epoch 5/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8353 - loss: 0.8550 - val_accuracy: 0.9373 - val_loss: 0.5184 - learning_rate: 1.0000e-04
# Epoch 6/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8880 - loss: 0.6798 - val_accuracy: 0.9565 - val_loss: 0.4150 - learning_rate: 1.0000e-04
# Epoch 7/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9222 - loss: 0.5548 - val_accuracy: 0.9642 - val_loss: 0.3617 - learning_rate: 1.0000e-04
# Epoch 8/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9396 - loss: 0.4807 - val_accuracy: 0.9706 - val_loss: 0.3208 - learning_rate: 1.0000e-04
# Epoch 9/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9487 - loss: 0.4314 - val_accuracy: 0.9712 - val_loss: 0.3043 - learning_rate: 1.0000e-04
# Epoch 10/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9572 - loss: 0.3869 - val_accuracy: 0.9761 - val_loss: 0.2769 - learning_rate: 1.0000e-04
# Epoch 11/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9622 - loss: 0.3568 - val_accuracy: 0.9772 - val_loss: 0.2634 - learning_rate: 1.0000e-04
# Epoch 12/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9660 - loss: 0.3325 - val_accuracy: 0.9822 - val_loss: 0.2437 - learning_rate: 1.0000e-04
# Epoch 13/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9694 - loss: 0.3121 - val_accuracy: 0.9833 - val_loss: 0.2343 - learning_rate: 1.0000e-04
# Epoch 14/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9719 - loss: 0.2947 - val_accuracy: 0.9829 - val_loss: 0.2304 - learning_rate: 1.0000e-04
# Epoch 15/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9755 - loss: 0.2747 - val_accuracy: 0.9820 - val_loss: 0.2280 - learning_rate: 1.0000e-04
# Epoch 16/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9754 - loss: 0.2670 - val_accuracy: 0.9845 - val_loss: 0.2153 - learning_rate: 1.0000e-04
# Epoch 17/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9781 - loss: 0.2511 - val_accuracy: 0.9872 - val_loss: 0.2010 - learning_rate: 1.0000e-04
# Epoch 18/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9810 - loss: 0.2390 - val_accuracy: 0.9865 - val_loss: 0.1972 - learning_rate: 1.0000e-04
# Epoch 19/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9811 - loss: 0.2316 - val_accuracy: 0.9884 - val_loss: 0.1892 - learning_rate: 1.0000e-04
# Epoch 20/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9814 - loss: 0.2249 - val_accuracy: 0.9891 - val_loss: 0.1838 - learning_rate: 1.0000e-04
# Epoch 21/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9836 - loss: 0.2143 - val_accuracy: 0.9882 - val_loss: 0.1821 - learning_rate: 1.0000e-04
# Epoch 22/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9838 - loss: 0.2072 - val_accuracy: 0.9877 - val_loss: 0.1823 - learning_rate: 1.0000e-04
# Epoch 23/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9847 - loss: 0.2004 - val_accuracy: 0.9893 - val_loss: 0.1726 - learning_rate: 1.0000e-04
# Epoch 24/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9840 - loss: 0.1955 - val_accuracy: 0.9907 - val_loss: 0.1623 - learning_rate: 1.0000e-04
# Epoch 25/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9856 - loss: 0.1882 - val_accuracy: 0.9907 - val_loss: 0.1636 - learning_rate: 1.0000e-04
# Epoch 26/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9863 - loss: 0.1820 - val_accuracy: 0.9868 - val_loss: 0.1758 - learning_rate: 1.0000e-04
# Epoch 27/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9858 - loss: 0.1791 - val_accuracy: 0.9892 - val_loss: 0.1601 - learning_rate: 1.0000e-04
# Epoch 28/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9872 - loss: 0.1710 - val_accuracy: 0.9892 - val_loss: 0.1581 - learning_rate: 1.0000e-04
# Epoch 29/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9878 - loss: 0.1678 - val_accuracy: 0.9913 - val_loss: 0.1487 - learning_rate: 1.0000e-04
# Epoch 30/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9885 - loss: 0.1626 - val_accuracy: 0.9923 - val_loss: 0.1437 - learning_rate: 1.0000e-04
# Epoch 31/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9884 - loss: 0.1576 - val_accuracy: 0.9909 - val_loss: 0.1482 - learning_rate: 1.0000e-04
# Epoch 32/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9896 - loss: 0.1539 - val_accuracy: 0.9899 - val_loss: 0.1470 - learning_rate: 1.0000e-04
# Epoch 33/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9879 - loss: 0.1561 - val_accuracy: 0.9906 - val_loss: 0.1423 - learning_rate: 1.0000e-04
# Epoch 34/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9899 - loss: 0.1490 - val_accuracy: 0.9899 - val_loss: 0.1424 - learning_rate: 1.0000e-04
# Epoch 35/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9894 - loss: 0.1457 - val_accuracy: 0.9923 - val_loss: 0.1337 - learning_rate: 1.0000e-04
# Epoch 36/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9888 - loss: 0.1439 - val_accuracy: 0.9923 - val_loss: 0.1300 - learning_rate: 1.0000e-04
# Epoch 37/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9905 - loss: 0.1388 - val_accuracy: 0.9912 - val_loss: 0.1322 - learning_rate: 1.0000e-04
# Epoch 38/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9899 - loss: 0.1365 - val_accuracy: 0.9919 - val_loss: 0.1280 - learning_rate: 1.0000e-04
# Epoch 39/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9906 - loss: 0.1328 - val_accuracy: 0.9912 - val_loss: 0.1283 - learning_rate: 1.0000e-04
# Epoch 40/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9902 - loss: 0.1311 - val_accuracy: 0.9909 - val_loss: 0.1319 - learning_rate: 1.0000e-04
# Epoch 41/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9916 - loss: 0.1263 - val_accuracy: 0.9898 - val_loss: 0.1322 - learning_rate: 1.0000e-04
# Epoch 42/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9926 - loss: 0.1219 - val_accuracy: 0.9933 - val_loss: 0.1170 - learning_rate: 1.0000e-04
# Epoch 43/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9912 - loss: 0.1241 - val_accuracy: 0.9935 - val_loss: 0.1147 - learning_rate: 1.0000e-04
# Epoch 44/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9914 - loss: 0.1209 - val_accuracy: 0.9930 - val_loss: 0.1137 - learning_rate: 1.0000e-04
# Epoch 45/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9924 - loss: 0.1158 - val_accuracy: 0.9926 - val_loss: 0.1140 - learning_rate: 1.0000e-04
# Epoch 46/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9924 - loss: 0.1149 - val_accuracy: 0.9918 - val_loss: 0.1183 - learning_rate: 1.0000e-04
# Epoch 47/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9921 - loss: 0.1132 - val_accuracy: 0.9920 - val_loss: 0.1143 - learning_rate: 1.0000e-04
# Epoch 48/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9920 - loss: 0.1139 - val_accuracy: 0.9927 - val_loss: 0.1104 - learning_rate: 1.0000e-04
# Epoch 49/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9929 - loss: 0.1091 - val_accuracy: 0.9900 - val_loss: 0.1177 - learning_rate: 1.0000e-04
# Epoch 50/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9927 - loss: 0.1075 - val_accuracy: 0.9903 - val_loss: 0.1188 - learning_rate: 1.0000e-04
# Epoch 51/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9934 - loss: 0.1028 - val_accuracy: 0.9912 - val_loss: 0.1116 - learning_rate: 1.0000e-04
# Epoch 52/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9929 - loss: 0.1042 - val_accuracy: 0.9912 - val_loss: 0.1093 - learning_rate: 1.0000e-04
# Epoch 53/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9934 - loss: 0.1006 - val_accuracy: 0.9919 - val_loss: 0.1087 - learning_rate: 1.0000e-04
# Epoch 54/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9934 - loss: 0.1003 - val_accuracy: 0.9930 - val_loss: 0.1045 - learning_rate: 1.0000e-04
# Epoch 55/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9942 - loss: 0.0964 - val_accuracy: 0.9921 - val_loss: 0.1057 - learning_rate: 1.0000e-04
# Epoch 56/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9934 - loss: 0.0970 - val_accuracy: 0.9918 - val_loss: 0.1054 - learning_rate: 1.0000e-04
# Epoch 57/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9934 - loss: 0.0974 - val_accuracy: 0.9927 - val_loss: 0.0985 - learning_rate: 1.0000e-04
# Epoch 58/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9933 - loss: 0.0937 - val_accuracy: 0.9922 - val_loss: 0.1019 - learning_rate: 1.0000e-04
# Epoch 59/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9948 - loss: 0.0905 - val_accuracy: 0.9932 - val_loss: 0.0956 - learning_rate: 1.0000e-04
# Epoch 60/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9940 - loss: 0.0919 - val_accuracy: 0.9923 - val_loss: 0.0983 - learning_rate: 1.0000e-04
# Epoch 61/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9936 - loss: 0.0915 - val_accuracy: 0.9928 - val_loss: 0.0969 - learning_rate: 1.0000e-04
# Epoch 62/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9940 - loss: 0.0875 - val_accuracy: 0.9921 - val_loss: 0.0968 - learning_rate: 1.0000e-04
# Epoch 63/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9943 - loss: 0.0852 - val_accuracy: 0.9927 - val_loss: 0.0945 - learning_rate: 1.0000e-04
# Epoch 64/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9952 - loss: 0.0835 - val_accuracy: 0.9936 - val_loss: 0.0928 - learning_rate: 1.0000e-04
# Epoch 65/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9942 - loss: 0.0848 - val_accuracy: 0.9934 - val_loss: 0.0915 - learning_rate: 1.0000e-04
# Epoch 66/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9947 - loss: 0.0814 - val_accuracy: 0.9929 - val_loss: 0.0918 - learning_rate: 1.0000e-04
# Epoch 67/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9945 - loss: 0.0825 - val_accuracy: 0.9942 - val_loss: 0.0868 - learning_rate: 1.0000e-04
# Epoch 68/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9953 - loss: 0.0780 - val_accuracy: 0.9921 - val_loss: 0.0939 - learning_rate: 1.0000e-04
# Epoch 69/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9945 - loss: 0.0785 - val_accuracy: 0.9927 - val_loss: 0.0901 - learning_rate: 1.0000e-04
# Epoch 70/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9943 - loss: 0.0781 - val_accuracy: 0.9928 - val_loss: 0.0880 - learning_rate: 1.0000e-04
# Epoch 71/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9952 - loss: 0.0763 - val_accuracy: 0.9930 - val_loss: 0.0841 - learning_rate: 1.0000e-04
# Epoch 72/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9951 - loss: 0.0756 - val_accuracy: 0.9932 - val_loss: 0.0861 - learning_rate: 1.0000e-04
# Epoch 73/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9962 - loss: 0.0723 - val_accuracy: 0.9937 - val_loss: 0.0845 - learning_rate: 1.0000e-04
# Epoch 74/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9954 - loss: 0.0723 - val_accuracy: 0.9943 - val_loss: 0.0816 - learning_rate: 1.0000e-04
# Epoch 75/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9953 - loss: 0.0728 - val_accuracy: 0.9941 - val_loss: 0.0793 - learning_rate: 1.0000e-04
# Epoch 76/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9963 - loss: 0.0696 - val_accuracy: 0.9944 - val_loss: 0.0802 - learning_rate: 1.0000e-04
# Epoch 77/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9960 - loss: 0.0691 - val_accuracy: 0.9926 - val_loss: 0.0849 - learning_rate: 1.0000e-04
# Epoch 78/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9953 - loss: 0.0705 - val_accuracy: 0.9934 - val_loss: 0.0788 - learning_rate: 1.0000e-04
# Epoch 79/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9955 - loss: 0.0680 - val_accuracy: 0.9936 - val_loss: 0.0808 - learning_rate: 1.0000e-04
# Epoch 80/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9952 - loss: 0.0700 - val_accuracy: 0.9927 - val_loss: 0.0868 - learning_rate: 1.0000e-04
# Epoch 81/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9956 - loss: 0.0670 - val_accuracy: 0.9935 - val_loss: 0.0795 - learning_rate: 1.0000e-04
# Epoch 82/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9957 - loss: 0.0662 - val_accuracy: 0.9942 - val_loss: 0.0769 - learning_rate: 1.0000e-04
# Epoch 83/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9962 - loss: 0.0638 - val_accuracy: 0.9937 - val_loss: 0.0801 - learning_rate: 1.0000e-04
# Epoch 84/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9954 - loss: 0.0661 - val_accuracy: 0.9920 - val_loss: 0.0860 - learning_rate: 1.0000e-04
# Epoch 85/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9968 - loss: 0.0614 - val_accuracy: 0.9935 - val_loss: 0.0772 - learning_rate: 1.0000e-04
# Epoch 86/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9962 - loss: 0.0631 - val_accuracy: 0.9937 - val_loss: 0.0785 - learning_rate: 1.0000e-04
# Epoch 87/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9968 - loss: 0.0596 - val_accuracy: 0.9945 - val_loss: 0.0734 - learning_rate: 1.0000e-04
# Epoch 88/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9962 - loss: 0.0618 - val_accuracy: 0.9937 - val_loss: 0.0743 - learning_rate: 1.0000e-04
# Epoch 89/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9967 - loss: 0.0592 - val_accuracy: 0.9934 - val_loss: 0.0769 - learning_rate: 1.0000e-04
# Epoch 90/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9970 - loss: 0.0580 - val_accuracy: 0.9938 - val_loss: 0.0735 - learning_rate: 1.0000e-04
# Epoch 91/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9965 - loss: 0.0593 - val_accuracy: 0.9934 - val_loss: 0.0780 - learning_rate: 1.0000e-04
# Epoch 92/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9968 - loss: 0.0574 - val_accuracy: 0.9938 - val_loss: 0.0721 - learning_rate: 1.0000e-04
# Epoch 93/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9966 - loss: 0.0569 - val_accuracy: 0.9915 - val_loss: 0.0854 - learning_rate: 1.0000e-04
# Epoch 94/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9963 - loss: 0.0574 - val_accuracy: 0.9937 - val_loss: 0.0731 - learning_rate: 1.0000e-04
# Epoch 95/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9968 - loss: 0.0568 - val_accuracy: 0.9940 - val_loss: 0.0709 - learning_rate: 1.0000e-04
# Epoch 96/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9960 - loss: 0.0567 - val_accuracy: 0.9937 - val_loss: 0.0714 - learning_rate: 1.0000e-04
# Epoch 97/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9960 - loss: 0.0566 - val_accuracy: 0.9945 - val_loss: 0.0684 - learning_rate: 1.0000e-04
# Epoch 98/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9965 - loss: 0.0556 - val_accuracy: 0.9945 - val_loss: 0.0694 - learning_rate: 1.0000e-04
# Epoch 99/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9969 - loss: 0.0532 - val_accuracy: 0.9939 - val_loss: 0.0708 - learning_rate: 1.0000e-04
# Epoch 100/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9970 - loss: 0.0511 - val_accuracy: 0.9938 - val_loss: 0.0700 - learning_rate: 1.0000e-04
# Epoch 101/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9969 - loss: 0.0508 - val_accuracy: 0.9948 - val_loss: 0.0679 - learning_rate: 1.0000e-04
# Epoch 102/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9961 - loss: 0.0531 - val_accuracy: 0.9947 - val_loss: 0.0682 - learning_rate: 1.0000e-04
# Epoch 103/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9967 - loss: 0.0523 - val_accuracy: 0.9946 - val_loss: 0.0651 - learning_rate: 1.0000e-04
# Epoch 104/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9966 - loss: 0.0506 - val_accuracy: 0.9940 - val_loss: 0.0681 - learning_rate: 1.0000e-04
# Epoch 105/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9969 - loss: 0.0501 - val_accuracy: 0.9949 - val_loss: 0.0659 - learning_rate: 1.0000e-04
# Epoch 106/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9969 - loss: 0.0506 - val_accuracy: 0.9946 - val_loss: 0.0643 - learning_rate: 1.0000e-04
# Epoch 107/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9973 - loss: 0.0493 - val_accuracy: 0.9934 - val_loss: 0.0689 - learning_rate: 1.0000e-04
# Epoch 108/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9967 - loss: 0.0504 - val_accuracy: 0.9942 - val_loss: 0.0635 - learning_rate: 1.0000e-04
# Epoch 109/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9967 - loss: 0.0492 - val_accuracy: 0.9938 - val_loss: 0.0680 - learning_rate: 1.0000e-04
# Epoch 110/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9969 - loss: 0.0486 - val_accuracy: 0.9939 - val_loss: 0.0674 - learning_rate: 1.0000e-04
# Epoch 111/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9966 - loss: 0.0483 - val_accuracy: 0.9932 - val_loss: 0.0684 - learning_rate: 1.0000e-04
# Epoch 112/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9973 - loss: 0.0466 - val_accuracy: 0.9944 - val_loss: 0.0606 - learning_rate: 1.0000e-04
# Epoch 113/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9968 - loss: 0.0467 - val_accuracy: 0.9946 - val_loss: 0.0652 - learning_rate: 1.0000e-04
# Epoch 114/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9971 - loss: 0.0464 - val_accuracy: 0.9923 - val_loss: 0.0741 - learning_rate: 1.0000e-04
# Epoch 115/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9972 - loss: 0.0472 - val_accuracy: 0.9948 - val_loss: 0.0612 - learning_rate: 1.0000e-04
# Epoch 116/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9972 - loss: 0.0450 - val_accuracy: 0.9948 - val_loss: 0.0613 - learning_rate: 1.0000e-04
# Epoch 117/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9974 - loss: 0.0449 - val_accuracy: 0.9941 - val_loss: 0.0630 - learning_rate: 1.0000e-04
# Epoch 118/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9973 - loss: 0.0441 - val_accuracy: 0.9942 - val_loss: 0.0615 - learning_rate: 1.0000e-04
# Epoch 119/200
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9975 - loss: 0.0434
# Epoch 119: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9975 - loss: 0.0434 - val_accuracy: 0.9937 - val_loss: 0.0640 - learning_rate: 1.0000e-04
# Epoch 120/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9975 - loss: 0.0434 - val_accuracy: 0.9942 - val_loss: 0.0623 - learning_rate: 5.0000e-05
# Epoch 121/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9978 - loss: 0.0418 - val_accuracy: 0.9955 - val_loss: 0.0589 - learning_rate: 5.0000e-05
# Epoch 122/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9981 - loss: 0.0402 - val_accuracy: 0.9944 - val_loss: 0.0618 - learning_rate: 5.0000e-05
# Epoch 123/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9979 - loss: 0.0410 - val_accuracy: 0.9952 - val_loss: 0.0601 - learning_rate: 5.0000e-05
# Epoch 124/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9983 - loss: 0.0400 - val_accuracy: 0.9954 - val_loss: 0.0571 - learning_rate: 5.0000e-05
# Epoch 125/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9979 - loss: 0.0412 - val_accuracy: 0.9953 - val_loss: 0.0588 - learning_rate: 5.0000e-05
# Epoch 126/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9985 - loss: 0.0385 - val_accuracy: 0.9945 - val_loss: 0.0598 - learning_rate: 5.0000e-05
# Epoch 127/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9980 - loss: 0.0404 - val_accuracy: 0.9944 - val_loss: 0.0601 - learning_rate: 5.0000e-05
# Epoch 128/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9984 - loss: 0.0393 - val_accuracy: 0.9948 - val_loss: 0.0609 - learning_rate: 5.0000e-05
# Epoch 129/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9980 - loss: 0.0389 - val_accuracy: 0.9944 - val_loss: 0.0593 - learning_rate: 5.0000e-05
# Epoch 130/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9982 - loss: 0.0396 - val_accuracy: 0.9948 - val_loss: 0.0578 - learning_rate: 5.0000e-05
# Epoch 131/200
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9986 - loss: 0.0375
# Epoch 131: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9986 - loss: 0.0375 - val_accuracy: 0.9946 - val_loss: 0.0586 - learning_rate: 5.0000e-05
# Epoch 132/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9981 - loss: 0.0381 - val_accuracy: 0.9954 - val_loss: 0.0560 - learning_rate: 2.5000e-05
# Epoch 133/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9986 - loss: 0.0373 - val_accuracy: 0.9958 - val_loss: 0.0567 - learning_rate: 2.5000e-05
# Epoch 134/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9987 - loss: 0.0362 - val_accuracy: 0.9953 - val_loss: 0.0558 - learning_rate: 2.5000e-05
# Epoch 135/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9981 - loss: 0.0375 - val_accuracy: 0.9948 - val_loss: 0.0576 - learning_rate: 2.5000e-05
# Epoch 136/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.9988 - loss: 0.0357 - val_accuracy: 0.9955 - val_loss: 0.0568 - learning_rate: 2.5000e-05
# Epoch 137/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9983 - loss: 0.0373 - val_accuracy: 0.9956 - val_loss: 0.0554 - learning_rate: 2.5000e-05
# Epoch 138/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9991 - loss: 0.0354 - val_accuracy: 0.9954 - val_loss: 0.0559 - learning_rate: 2.5000e-05
# Epoch 139/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9991 - loss: 0.0355 - val_accuracy: 0.9955 - val_loss: 0.0569 - learning_rate: 2.5000e-05
# Epoch 140/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9990 - loss: 0.0358 - val_accuracy: 0.9951 - val_loss: 0.0573 - learning_rate: 2.5000e-05
# Epoch 141/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9993 - loss: 0.0347 - val_accuracy: 0.9947 - val_loss: 0.0589 - learning_rate: 2.5000e-05
# Epoch 142/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9991 - loss: 0.0351 - val_accuracy: 0.9947 - val_loss: 0.0588 - learning_rate: 2.5000e-05
# Epoch 143/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9986 - loss: 0.0361 - val_accuracy: 0.9942 - val_loss: 0.0596 - learning_rate: 2.5000e-05
# Epoch 144/200
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9984 - loss: 0.0360
# Epoch 144: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9984 - loss: 0.0360 - val_accuracy: 0.9948 - val_loss: 0.0584 - learning_rate: 2.5000e-05
# Epoch 145/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9990 - loss: 0.0347 - val_accuracy: 0.9948 - val_loss: 0.0571 - learning_rate: 1.2500e-05
# Epoch 146/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9990 - loss: 0.0342 - val_accuracy: 0.9948 - val_loss: 0.0570 - learning_rate: 1.2500e-05
# Epoch 147/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9989 - loss: 0.0350 - val_accuracy: 0.9949 - val_loss: 0.0571 - learning_rate: 1.2500e-05
# Epoch 148/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9989 - loss: 0.0343 - val_accuracy: 0.9953 - val_loss: 0.0572 - learning_rate: 1.2500e-05
# Epoch 149/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9991 - loss: 0.0341 - val_accuracy: 0.9951 - val_loss: 0.0558 - learning_rate: 1.2500e-05
# Epoch 149: early stopping
# Restoring model weights from the end of the best epoch: 137.
# Final Training Loss:            0.0348
# Final Training Accuracy:        0.9989
# Final Validation Loss:          0.0558
# Final Validation Accuracy:      0.9951
# Minimum Validation Loss:        0.0554 (Epoch 137)
# Validation Accuracy @ Min Loss: 0.9956
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9931 - loss: 0.0594
#
# Test Accuracy: 0.9949
# Test Loss: 0.0535
#
# Validation-Test Gap (accuracy): 0.000683
#
# Execution Time: 00:16:11

# %% [markdown]
# Same but with L2 regularization in all layers.
#
# Current best model, essentially tied with previous.
#
# Currently trying chatGPT's advice.

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    # SpatialDropout2D(0.25),
    Dropout(0.25),

        # --- Convolutional Block 3 ---                         # This was added to original design
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    # SpatialDropout2D(0.25),
    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x7a73bdd80>]
# Final Training Loss:            0.0424
# Final Training Accuracy:        0.9996
# Final Validation Loss:          0.0660
# Final Validation Accuracy:      0.9949
# Minimum Validation Loss:        0.0646 (Epoch 144)
# Validation Accuracy @ Min Loss: 0.9956
#
# Test Accuracy: 0.9949
# Test Loss: 0.0653
#
# Validation-Test Gap (accuracy): 0.000683
#
# Execution Time: 00:16:39

# %% [markdown]
# ### 11. Deep Network With Data Augmentation Layer

# %%
# 1) Define your augmentation block without its own InputLayer
data_augmentation = models.Sequential(
    [
        layers.RandomRotation(0.1,         fill_mode="nearest"),  # ±10% of 2π ⇒ ±36°
        layers.RandomZoom(0.1,             fill_mode="nearest"),
        layers.RandomTranslation(0.1, 0.1, fill_mode="nearest"),
    ],
)



#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    data_augmentation,

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    # SpatialDropout2D(0.25),
    Dropout(0.25),

        # --- Convolutional Block 3 ---                         # This was added to original design
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    # SpatialDropout2D(0.25),
    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x810598250>]
# Final Training Loss:            0.0663
# Final Training Accuracy:        0.9935
# Final Validation Loss:          0.0655
# Final Validation Accuracy:      0.9954
# Minimum Validation Loss:        0.0647 (Epoch 198)
# Validation Accuracy @ Min Loss: 0.9947
#
# Test Accuracy: 0.9945
# Test Loss: 0.0626
#
# Validation-Test Gap (accuracy): 0.000167
#
# Execution Time: 00:25:09

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    


    
    # --- Fully Connected Block ---
    # GlobalAveragePooling2D(),                                    # Original used Flatten()
    Flatten(),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x6ced3b400>]
# Final Training Loss:            0.0198
# Final Training Accuracy:        0.9996
# Final Validation Loss:          0.0496
# Final Validation Accuracy:      0.9911
# Minimum Validation Loss:        0.0491 (Epoch 78)
# Validation Accuracy @ Min Loss: 0.9910
#
# Test Accuracy: 0.9916
# Test Loss: 0.0457
#
# Validation-Test Gap (accuracy): 0.000600
#
# Execution Time: 00:05:27

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    


    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x6bdfd2b60>]
# Final Training Loss:            0.0497
# Final Training Accuracy:        0.9953
# Final Validation Loss:          0.0594
# Final Validation Accuracy:      0.9938
# Minimum Validation Loss:        0.0590 (Epoch 165)
# Validation Accuracy @ Min Loss: 0.9940
#
# Test Accuracy: 0.9937
# Test Loss: 0.0571
#
# Validation-Test Gap (accuracy): 0.000300
#
# Execution Time: 00:15:46

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    
    # --- Convolutional Block 2 ---
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()

    Dense(256, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    
    # --- Convolutional Block 2 ---
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(512, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(512, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()

    Dense(1024, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(256, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x9b55b43d0>]
# Final Training Loss:            0.0620
# Final Training Accuracy:        0.9990
# Final Validation Loss:          0.0937
# Final Validation Accuracy:      0.9941
# Minimum Validation Loss:        0.0904 (Epoch 146)
# Validation Accuracy @ Min Loss: 0.9951
#
# Test Accuracy: 0.9943
# Test Loss: 0.0957
#
# Validation-Test Gap (accuracy): 0.000783
#
# Execution Time: 00:44:15

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    
    # --- Convolutional Block 2 ---
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(256, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(256, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()

    Dense(512, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(256, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)


train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0x5ff28b010>]
# Final Training Loss:            0.0694
# Final Training Accuracy:        0.9998
# Final Validation Loss:          0.1042
# Final Validation Accuracy:      0.9943
# Minimum Validation Loss:        0.1029 (Epoch 166)
# Validation Accuracy @ Min Loss: 0.9944
#
# Test Accuracy: 0.9948
# Test Loss: 0.1029
#
# Validation-Test Gap (accuracy): 0.000383
#
# Execution Time: 00:48:27

# %% [markdown]
# ### Best Model
#
# Conv: 32; 64; 128 Dense 128 64 10
# L2 Regularization
# Spatial Dropout

# %%
#  Same but used L2 in all layers

from tensorflow.keras import models, layers, regularizers

from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, SpatialDropout2D

conv_l2   = 1e-4
dense_l2  = 7.5e-4

model_deep_3 = models.Sequential([

    # --- Input Layer ---
    Input(shape=(28, 28, 1)),

    # --- Convolutional Block 1 ---
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(32, kernel_size=5, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),

    # --- Convolutional Block 2 ---
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(64, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    

        # --- Convolutional Block 3 ---                         # This was added to original design
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           activation='relu',
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    Conv2D(128, kernel_size=3, strides=1, padding='same',
           use_bias=False,
           kernel_regularizer=regularizers.l2(conv_l2),
           kernel_initializer='he_normal'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=2, strides=2),
    SpatialDropout2D(0.25),
    # Dropout(0.25),
    
    # --- Fully Connected Block ---
    GlobalAveragePooling2D(),                                    # Original used Flatten()
    
    Dense(128, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    Dense(64, use_bias=False, kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(dense_l2)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.25),

    # --- Output Layer ---
    Dense(10, activation='softmax')
])

variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=0
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)
global_epochs = 300

train_and_test(
    model_deep_3,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.00001,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 0
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  lr_schedule: 1e-05	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0xe7e281570>]
# Final Training Loss:            0.1698
# Final Training Accuracy:        0.9911
# Final Validation Loss:          0.1691
# Final Validation Accuracy:      0.9914
# Minimum Validation Loss:        0.1691 (Epoch 300)
# Validation Accuracy @ Min Loss: 0.9914
#
# Test Accuracy: 0.9939
# Test Loss: 0.1579
#
# Validation-Test Gap (accuracy): 0.002483
#
# Execution Time: 00:33:54

# %% [markdown]
# Initial LR: 0.
#
# ![Screenshot 2025-07-17 at 8.44.18 PM.png](attachment:6486f6f6-4951-4eff-919d-39536ca6a9c8.png)

# %%
from tensorflow.keras import models, layers, regularizers

# ----- Hyper‑parameters -------------------------------------------------
conv_l2   = 1e-4
dense_l2  = 7.5e-4

# ----- Residual block helper -------------------------------------------
def residual_block(x, filters, k=3, down=False, name=None):
    """
    Basic two‑conv residual block (v1 style).
    If `down=True` the first conv uses stride 2, so the block halves H,W.
    If input channels ≠ filters, the shortcut is projected with 1×1 conv.
    """
    stride = 2 if down else 1
    shortcut = x

    # ----- conv‑BN‑ReLU 1 -----
    x = layers.Conv2D(filters, k, padding="same", strides=stride,
                      use_bias=False,
                      kernel_regularizer=regularizers.l2(conv_l2),
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    # ----- conv‑BN 2 -----
    x = layers.Conv2D(filters, k, padding="same", strides=1,
                      use_bias=False,
                      kernel_regularizer=regularizers.l2(conv_l2),
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)

    # ----- shortcut -----
    if down or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, padding="same", strides=stride,
                                 use_bias=False,
                                 kernel_regularizer=regularizers.l2(conv_l2),
                                 kernel_initializer="he_normal")(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    # ----- merge -----
    x = layers.add([x, shortcut])
    x = layers.Activation("relu")(x)
    return x

# ----- Model definition -------------------------------------------------
inputs = layers.Input(shape=(28, 28, 1))

# Block 1: 32 filters, keep resolution, then pool by stride=2 via residual
x = residual_block(inputs, 32, k=5, down=False)   # 28×28×32
x = layers.SpatialDropout2D(0.25)(x)
x = residual_block(x, 32, k=5, down=True)         # 14×14×32

# Block 2: 64 filters
x = residual_block(x, 64, k=3, down=False)        # 14×14×64
x = layers.SpatialDropout2D(0.25)(x)
x = residual_block(x, 64, k=3, down=True)         # 7×7×64

# Block 3: 128 filters
x = residual_block(x, 128, k=3, down=False)       # 7×7×128
x = layers.SpatialDropout2D(0.25)(x)
x = residual_block(x, 128, k=3, down=True)        # 3×3×128

# Global pooling and dense head
x = layers.GlobalAveragePooling2D()(x)            # 128 features
x = layers.Dense(128, use_bias=False,
                 kernel_initializer="he_normal",
                 kernel_regularizer=regularizers.l2(dense_l2))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.Dropout(0.25)(x)

x = layers.Dense(64, use_bias=False,
                 kernel_initializer="he_normal",
                 kernel_regularizer=regularizers.l2(dense_l2))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.Dropout(0.25)(x)

outputs = layers.Dense(10, activation="softmax")(x)

model_resnet = models.Model(inputs, outputs, name="MNIST_ResNet_like")


variable_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # cut LR in half
    patience=7,       # wait 5 epochs with no improvement
    min_delta=1e-4,   # must beat val_loss by at least 0.001
    min_lr=1e-8,
    verbose=1
)

# optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-4)
global_epochs = 300

train_and_test(
    model_resnet,                 # <- note the correct model name
    epochs=global_epochs,
    # optimizer = optimizer,
    lr_schedule=0.0005,             # let the callback handle LR
    use_early_stopping = True,
   patience      = 12,                     # To turn off early stopping, set patience to same as epochs
   min_delta     = 0.0001,
    callbacks=[variable_learning_rate],
    batch_size=256,               # smoother gradients
    title="Deep 3 Medium 2 – SpatialDropout",
    verbose= 1
)
# Out:
# Deep 3 Medium 2 – SpatialDropout:  lr_schedule: 0.0005	patience: 12	min_delta: 0.0001	callbacks: [<keras.src.callbacks.reduce_lr_on_plateau.ReduceLROnPlateau object at 0xcb98df670>]
#
# Epoch 1/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - accuracy: 0.3701 - loss: 2.4342 - val_accuracy: 0.8605 - val_loss: 1.0990 - learning_rate: 5.0000e-04
# Epoch 2/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9192 - loss: 0.8620 - val_accuracy: 0.9671 - val_loss: 0.6201 - learning_rate: 5.0000e-04
# Epoch 3/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9623 - loss: 0.6431 - val_accuracy: 0.9764 - val_loss: 0.5364 - learning_rate: 5.0000e-04
# Epoch 4/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9734 - loss: 0.5531 - val_accuracy: 0.9837 - val_loss: 0.4773 - learning_rate: 5.0000e-04
# Epoch 5/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9812 - loss: 0.4845 - val_accuracy: 0.9764 - val_loss: 0.4668 - learning_rate: 5.0000e-04
# Epoch 6/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9837 - loss: 0.4339 - val_accuracy: 0.9877 - val_loss: 0.3918 - learning_rate: 5.0000e-04
# Epoch 7/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9865 - loss: 0.3913 - val_accuracy: 0.9880 - val_loss: 0.3603 - learning_rate: 5.0000e-04
# Epoch 8/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9894 - loss: 0.3540 - val_accuracy: 0.9858 - val_loss: 0.3387 - learning_rate: 5.0000e-04
# Epoch 9/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9899 - loss: 0.3229 - val_accuracy: 0.9869 - val_loss: 0.3177 - learning_rate: 5.0000e-04
# Epoch 10/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9898 - loss: 0.3004 - val_accuracy: 0.9859 - val_loss: 0.2947 - learning_rate: 5.0000e-04
# Epoch 11/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9902 - loss: 0.2789 - val_accuracy: 0.9904 - val_loss: 0.2655 - learning_rate: 5.0000e-04
# Epoch 12/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9903 - loss: 0.2602 - val_accuracy: 0.9885 - val_loss: 0.2575 - learning_rate: 5.0000e-04
# Epoch 13/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9933 - loss: 0.2373 - val_accuracy: 0.9898 - val_loss: 0.2359 - learning_rate: 5.0000e-04
# Epoch 14/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9921 - loss: 0.2270 - val_accuracy: 0.9901 - val_loss: 0.2256 - learning_rate: 5.0000e-04
# Epoch 15/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9915 - loss: 0.2165 - val_accuracy: 0.9908 - val_loss: 0.2155 - learning_rate: 5.0000e-04
# Epoch 16/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9923 - loss: 0.1999 - val_accuracy: 0.9910 - val_loss: 0.2044 - learning_rate: 5.0000e-04
# Epoch 17/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - accuracy: 0.9932 - loss: 0.1906 - val_accuracy: 0.9912 - val_loss: 0.1951 - learning_rate: 5.0000e-04
# Epoch 18/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9940 - loss: 0.1807 - val_accuracy: 0.9905 - val_loss: 0.1867 - learning_rate: 5.0000e-04
# Epoch 19/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9933 - loss: 0.1738 - val_accuracy: 0.9900 - val_loss: 0.1836 - learning_rate: 5.0000e-04
# Epoch 20/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9939 - loss: 0.1646 - val_accuracy: 0.9910 - val_loss: 0.1740 - learning_rate: 5.0000e-04
# Epoch 21/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9932 - loss: 0.1599 - val_accuracy: 0.9909 - val_loss: 0.1715 - learning_rate: 5.0000e-04
# Epoch 22/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9948 - loss: 0.1483 - val_accuracy: 0.9898 - val_loss: 0.1677 - learning_rate: 5.0000e-04
# Epoch 23/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9951 - loss: 0.1425 - val_accuracy: 0.9908 - val_loss: 0.1595 - learning_rate: 5.0000e-04
# Epoch 24/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9933 - loss: 0.1429 - val_accuracy: 0.9915 - val_loss: 0.1489 - learning_rate: 5.0000e-04
# Epoch 25/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9957 - loss: 0.1309 - val_accuracy: 0.9899 - val_loss: 0.1551 - learning_rate: 5.0000e-04
# Epoch 26/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9947 - loss: 0.1269 - val_accuracy: 0.9912 - val_loss: 0.1419 - learning_rate: 5.0000e-04
# Epoch 27/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9946 - loss: 0.1231 - val_accuracy: 0.9895 - val_loss: 0.1472 - learning_rate: 5.0000e-04
# Epoch 28/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9953 - loss: 0.1192 - val_accuracy: 0.9873 - val_loss: 0.1553 - learning_rate: 5.0000e-04
# Epoch 29/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9946 - loss: 0.1187 - val_accuracy: 0.9900 - val_loss: 0.1336 - learning_rate: 5.0000e-04
# Epoch 30/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9955 - loss: 0.1115 - val_accuracy: 0.9898 - val_loss: 0.1333 - learning_rate: 5.0000e-04
# Epoch 31/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9949 - loss: 0.1098 - val_accuracy: 0.9910 - val_loss: 0.1298 - learning_rate: 5.0000e-04
# Epoch 32/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9961 - loss: 0.1028 - val_accuracy: 0.9918 - val_loss: 0.1226 - learning_rate: 5.0000e-04
# Epoch 33/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9953 - loss: 0.1029 - val_accuracy: 0.9906 - val_loss: 0.1199 - learning_rate: 5.0000e-04
# Epoch 34/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9965 - loss: 0.0965 - val_accuracy: 0.9903 - val_loss: 0.1207 - learning_rate: 5.0000e-04
# Epoch 35/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9950 - loss: 0.0980 - val_accuracy: 0.9914 - val_loss: 0.1132 - learning_rate: 5.0000e-04
# Epoch 36/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9954 - loss: 0.0936 - val_accuracy: 0.9930 - val_loss: 0.1084 - learning_rate: 5.0000e-04
# Epoch 37/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9962 - loss: 0.0903 - val_accuracy: 0.9904 - val_loss: 0.1197 - learning_rate: 5.0000e-04
# Epoch 38/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9957 - loss: 0.0909 - val_accuracy: 0.9895 - val_loss: 0.1146 - learning_rate: 5.0000e-04
# Epoch 39/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9955 - loss: 0.0885 - val_accuracy: 0.9919 - val_loss: 0.1092 - learning_rate: 5.0000e-04
# Epoch 40/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9963 - loss: 0.0844 - val_accuracy: 0.9915 - val_loss: 0.1055 - learning_rate: 5.0000e-04
# Epoch 41/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9956 - loss: 0.0872 - val_accuracy: 0.9925 - val_loss: 0.1011 - learning_rate: 5.0000e-04
# Epoch 42/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9955 - loss: 0.0832 - val_accuracy: 0.9912 - val_loss: 0.1029 - learning_rate: 5.0000e-04
# Epoch 43/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9950 - loss: 0.0821 - val_accuracy: 0.9905 - val_loss: 0.1071 - learning_rate: 5.0000e-04
# Epoch 44/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9961 - loss: 0.0785 - val_accuracy: 0.9920 - val_loss: 0.1003 - learning_rate: 5.0000e-04
# Epoch 45/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9949 - loss: 0.0810 - val_accuracy: 0.9929 - val_loss: 0.0982 - learning_rate: 5.0000e-04
# Epoch 46/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9967 - loss: 0.0755 - val_accuracy: 0.9901 - val_loss: 0.1077 - learning_rate: 5.0000e-04
# Epoch 47/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9963 - loss: 0.0750 - val_accuracy: 0.9906 - val_loss: 0.1009 - learning_rate: 5.0000e-04
# Epoch 48/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9964 - loss: 0.0740 - val_accuracy: 0.9912 - val_loss: 0.1029 - learning_rate: 5.0000e-04
# Epoch 49/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9958 - loss: 0.0753 - val_accuracy: 0.9885 - val_loss: 0.1120 - learning_rate: 5.0000e-04
# Epoch 50/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9966 - loss: 0.0702 - val_accuracy: 0.9909 - val_loss: 0.1043 - learning_rate: 5.0000e-04
# Epoch 51/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9971 - loss: 0.0707 - val_accuracy: 0.9898 - val_loss: 0.1020 - learning_rate: 5.0000e-04
# Epoch 52/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9969 - loss: 0.0686 - val_accuracy: 0.9912 - val_loss: 0.0976 - learning_rate: 5.0000e-04
# Epoch 53/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9953 - loss: 0.0724 - val_accuracy: 0.9904 - val_loss: 0.1002 - learning_rate: 5.0000e-04
# Epoch 54/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9969 - loss: 0.0669 - val_accuracy: 0.9925 - val_loss: 0.0864 - learning_rate: 5.0000e-04
# Epoch 55/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9973 - loss: 0.0649 - val_accuracy: 0.9891 - val_loss: 0.0995 - learning_rate: 5.0000e-04
# Epoch 56/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9964 - loss: 0.0671 - val_accuracy: 0.9904 - val_loss: 0.0934 - learning_rate: 5.0000e-04
# Epoch 57/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9976 - loss: 0.0613 - val_accuracy: 0.9879 - val_loss: 0.1126 - learning_rate: 5.0000e-04
# Epoch 58/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9955 - loss: 0.0679 - val_accuracy: 0.9883 - val_loss: 0.1047 - learning_rate: 5.0000e-04
# Epoch 59/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9959 - loss: 0.0686 - val_accuracy: 0.9916 - val_loss: 0.0848 - learning_rate: 5.0000e-04
# Epoch 60/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9974 - loss: 0.0637 - val_accuracy: 0.9927 - val_loss: 0.0834 - learning_rate: 5.0000e-04
# Epoch 61/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9964 - loss: 0.0641 - val_accuracy: 0.9919 - val_loss: 0.0858 - learning_rate: 5.0000e-04
# Epoch 62/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9968 - loss: 0.0629 - val_accuracy: 0.9924 - val_loss: 0.0807 - learning_rate: 5.0000e-04
# Epoch 63/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9969 - loss: 0.0611 - val_accuracy: 0.9923 - val_loss: 0.0873 - learning_rate: 5.0000e-04
# Epoch 64/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9963 - loss: 0.0607 - val_accuracy: 0.9903 - val_loss: 0.0934 - learning_rate: 5.0000e-04
# Epoch 65/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9967 - loss: 0.0610 - val_accuracy: 0.9899 - val_loss: 0.0968 - learning_rate: 5.0000e-04
# Epoch 66/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9972 - loss: 0.0597 - val_accuracy: 0.9908 - val_loss: 0.0891 - learning_rate: 5.0000e-04
# Epoch 67/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9979 - loss: 0.0576 - val_accuracy: 0.9923 - val_loss: 0.0841 - learning_rate: 5.0000e-04
# Epoch 68/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9974 - loss: 0.0573 - val_accuracy: 0.9916 - val_loss: 0.0848 - learning_rate: 5.0000e-04
# Epoch 69/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9971 - loss: 0.0564
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9971 - loss: 0.0564 - val_accuracy: 0.9918 - val_loss: 0.0898 - learning_rate: 5.0000e-04
# Epoch 70/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9979 - loss: 0.0534 - val_accuracy: 0.9948 - val_loss: 0.0715 - learning_rate: 2.5000e-04
# Epoch 71/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9992 - loss: 0.0480 - val_accuracy: 0.9944 - val_loss: 0.0715 - learning_rate: 2.5000e-04
# Epoch 72/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9994 - loss: 0.0455 - val_accuracy: 0.9942 - val_loss: 0.0702 - learning_rate: 2.5000e-04
# Epoch 73/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9997 - loss: 0.0432 - val_accuracy: 0.9932 - val_loss: 0.0718 - learning_rate: 2.5000e-04
# Epoch 74/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9990 - loss: 0.0435 - val_accuracy: 0.9917 - val_loss: 0.0792 - learning_rate: 2.5000e-04
# Epoch 75/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9987 - loss: 0.0439 - val_accuracy: 0.9932 - val_loss: 0.0740 - learning_rate: 2.5000e-04
# Epoch 76/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9988 - loss: 0.0420 - val_accuracy: 0.9919 - val_loss: 0.0805 - learning_rate: 2.5000e-04
# Epoch 77/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9982 - loss: 0.0434 - val_accuracy: 0.9933 - val_loss: 0.0715 - learning_rate: 2.5000e-04
# Epoch 78/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9983 - loss: 0.0423 - val_accuracy: 0.9936 - val_loss: 0.0692 - learning_rate: 2.5000e-04
# Epoch 79/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9989 - loss: 0.0404 - val_accuracy: 0.9934 - val_loss: 0.0668 - learning_rate: 2.5000e-04
# Epoch 80/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9985 - loss: 0.0417 - val_accuracy: 0.9919 - val_loss: 0.0723 - learning_rate: 2.5000e-04
# Epoch 81/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9987 - loss: 0.0402 - val_accuracy: 0.9934 - val_loss: 0.0666 - learning_rate: 2.5000e-04
# Epoch 82/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9991 - loss: 0.0386 - val_accuracy: 0.9933 - val_loss: 0.0681 - learning_rate: 2.5000e-04
# Epoch 83/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9991 - loss: 0.0373 - val_accuracy: 0.9932 - val_loss: 0.0679 - learning_rate: 2.5000e-04
# Epoch 84/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9984 - loss: 0.0396 - val_accuracy: 0.9928 - val_loss: 0.0715 - learning_rate: 2.5000e-04
# Epoch 85/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9983 - loss: 0.0385 - val_accuracy: 0.9923 - val_loss: 0.0708 - learning_rate: 2.5000e-04
# Epoch 86/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9988 - loss: 0.0388 - val_accuracy: 0.9916 - val_loss: 0.0769 - learning_rate: 2.5000e-04
# Epoch 87/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9985 - loss: 0.0382 - val_accuracy: 0.9923 - val_loss: 0.0712 - learning_rate: 2.5000e-04
# Epoch 88/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9986 - loss: 0.0372
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9986 - loss: 0.0372 - val_accuracy: 0.9923 - val_loss: 0.0732 - learning_rate: 2.5000e-04
# Epoch 89/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9993 - loss: 0.0348 - val_accuracy: 0.9946 - val_loss: 0.0589 - learning_rate: 1.2500e-04
# Epoch 90/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9999 - loss: 0.0323 - val_accuracy: 0.9938 - val_loss: 0.0602 - learning_rate: 1.2500e-04
# Epoch 91/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9995 - loss: 0.0319 - val_accuracy: 0.9942 - val_loss: 0.0609 - learning_rate: 1.2500e-04
# Epoch 92/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9998 - loss: 0.0310 - val_accuracy: 0.9943 - val_loss: 0.0599 - learning_rate: 1.2500e-04
# Epoch 93/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9999 - loss: 0.0300 - val_accuracy: 0.9934 - val_loss: 0.0604 - learning_rate: 1.2500e-04
# Epoch 94/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9999 - loss: 0.0293 - val_accuracy: 0.9942 - val_loss: 0.0621 - learning_rate: 1.2500e-04
# Epoch 95/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9995 - loss: 0.0303 - val_accuracy: 0.9943 - val_loss: 0.0605 - learning_rate: 1.2500e-04
# Epoch 96/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9998 - loss: 0.0285
# Epoch 96: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9998 - loss: 0.0285 - val_accuracy: 0.9945 - val_loss: 0.0602 - learning_rate: 1.2500e-04
# Epoch 97/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9998 - loss: 0.0275 - val_accuracy: 0.9948 - val_loss: 0.0561 - learning_rate: 6.2500e-05
# Epoch 98/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9999 - loss: 0.0269 - val_accuracy: 0.9950 - val_loss: 0.0554 - learning_rate: 6.2500e-05
# Epoch 99/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9998 - loss: 0.0267 - val_accuracy: 0.9946 - val_loss: 0.0581 - learning_rate: 6.2500e-05
# Epoch 100/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9999 - loss: 0.0263 - val_accuracy: 0.9940 - val_loss: 0.0583 - learning_rate: 6.2500e-05
# Epoch 101/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9999 - loss: 0.0260 - val_accuracy: 0.9948 - val_loss: 0.0572 - learning_rate: 6.2500e-05
# Epoch 102/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 1.0000 - loss: 0.0253 - val_accuracy: 0.9949 - val_loss: 0.0582 - learning_rate: 6.2500e-05
# Epoch 103/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9999 - loss: 0.0250 - val_accuracy: 0.9945 - val_loss: 0.0570 - learning_rate: 6.2500e-05
# Epoch 104/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9999 - loss: 0.0247 - val_accuracy: 0.9944 - val_loss: 0.0564 - learning_rate: 6.2500e-05
# Epoch 105/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9998 - loss: 0.0250
# Epoch 105: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9998 - loss: 0.0250 - val_accuracy: 0.9941 - val_loss: 0.0583 - learning_rate: 6.2500e-05
# Epoch 106/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9999 - loss: 0.0239 - val_accuracy: 0.9941 - val_loss: 0.0589 - learning_rate: 3.1250e-05
# Epoch 107/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 0.9941 - val_loss: 0.0583 - learning_rate: 3.1250e-05
# Epoch 108/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 1.0000 - loss: 0.0232 - val_accuracy: 0.9943 - val_loss: 0.0578 - learning_rate: 3.1250e-05
# Epoch 109/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.9945 - val_loss: 0.0575 - learning_rate: 3.1250e-05
# Epoch 110/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 0.9944 - val_loss: 0.0570 - learning_rate: 3.1250e-05
# Epoch 110: early stopping
# Restoring model weights from the end of the best epoch: 98.
# Final Training Loss:            0.0226
# Final Training Accuracy:        1.0000
# Final Validation Loss:          0.0570
# Final Validation Accuracy:      0.9944
# Minimum Validation Loss:        0.0554 (Epoch 98)
# Validation Accuracy @ Min Loss: 0.9950
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9942 - loss: 0.0593
#
# Test Accuracy: 0.9956
# Test Loss: 0.0513
#
# Validation-Test Gap (accuracy): 0.000600
#
# Execution Time: 00:37:06

# %%
notebook_end = time.time()
print(f"Notebook Execution Time: " + format_hms(notebook_end-notebook_start))

# %%
# Print results sorted by accuracy (highest → lowest)

for title, (acc, ep) in sorted(results.items(), 
                               key=lambda kv: kv[1][0],   # kv[1] is (acc, epoch); [0] is acc
                               reverse=True):
    print(f"{title:<40}\t{acc:.4f} @ {ep}")
# Out:
# Deep 3 Medium 2 – SpatialDropout        	0.9961 @ 158
# Deep CNN                                	0.9943 @ 16
# Deep CNN & GAP                          	0.9942 @ 28
# Deep 3 Medium 2 plus chatGPT            	0.9929 @ 25
# Deep 3 Medium 2 plus chatGPT & Augmentation	0.9929 @ 2
# Deep 2 from Medium                      	0.9922 @ 200

# %% [markdown]
# ## Appendix One:  Some "Rules of Thumb" for CNNs
#
# ### Architecture & Ordering
#
# 1. **Use Blocks of Conv → BatchNorm → ReLU**
#    Normalize first, then add non-linearity for stabler gradients.
# 2. **Small filters, deep network**
#    Stacks of 3 × 3 give the same receptive field as one 7 × 7 but with fewer weights.
# 3. **Halve size, double channels**
#    When you down-sample (stride 2 or max-pool), bump filters 2× to keep capacity.
# 4. **GlobalAvgPool beats huge Dense blocks**
#    Replaces tens of thousands of weights with a single spatial average.
#
# ### Regularization & Initialization
#
# 5. **Dropout after Dense (or SpatialDropout after Conv)**
#    Standard dropout ignores spatial structure; use it where it hurts least.
# 6. **He init for ReLU, Glorot for tanh**
#    Pick an initializer that matches your activation to avoid vanishing/exploding activations.
# 7. **Weight decay ≈ 1e-4 by default**
#    A little ℓ2 keeps weights from drifting without heavy hyper-tuning.
#
# ### Data & Training
#
# 8. **Normalize inputs early, augment on the fly**
#    Centering/scaling once; flip/crop/shift every epoch for fresh variety.
# 9. **Learning-rate schedule > optimizer tweaks**
#    A good decay (exponential, cosine, OneCycle) usually beats exotic optimizers.
# 10. **Batch size: fit the GPU, don’t chase myths**
#     Use the largest batch that fits memory; tune LR if you change it.
#
# ### Monitoring & Debugging
#
# 11. **Watch train vs. val curves, not just accuracy**
#     Divergence signals overfitting; flat lines signal undercapacity or bad LR.
# 12. **First sanity check: overfit a tiny subset**
#     If the model can’t hit 100 % on 10 images, something else is broken.

# %% [markdown]
# ## Appendix Two: Data Augmentation
#
#
# One of the most powerful tools in your toolbox for image processing is Data Augmentation—the process of creating additional training samples by changing various characteristics of the image that do not change its essential character:
#
# - Geometry: rotation, flipping horizontally or vertically, zooming, shifting;
# - Photometrics: Brightness, contrast, blur, saturation and hue shifts;
# - Cropping and Rescaling: select certain parts of the image or change range of pixel values.
#
# Other, more sophisticated approaches include overlaying one image over another, or moving objects localized in one image into another image.
#
#
# Data augmentation is a powerful tool to improve the performance of CNNs by synthetically increasing the diversity of your training dataset—without collecting new data. By training the model to handle real-world noise and variability, it helps models generalize better and reduces the risk of overfitting.
#
#
# ![Screenshot 2025-07-13 at 1.40.47 PM.png](attachment:8b8f3e27-4a6c-4872-9964-44ade8686db7.png)
#
#
# Data Augmentation can be performed “on the fly” by adding layers to the network, or by explicitly adding new samples to your dataset. The first approach is generally only usable when relatively simple transformations are applied. Keras supports the following layer transformations:
#
# - RandomFlip (horizontal or vertical),
# - RandomRotation,
# - RandomZoom,
# - RandomTranslation,
# - RandomContrast, and
# - RandomBrightness.
#
# These layers apply randomized but label-preserving transformations directly to the input images during training—without modifying the original dataset—making them ideal for real-time augmentation with minimal memory overhead.
#
# When is Augmentation not Appropriate?
#
# - Use it during training only—not on validation/test sets.
# - Avoid excessive augmentation that alters the semantic content (e.g., flipping text or distorting faces unnaturally).
# - Use domain-specific logic:
#     - Don’t flip chest X-rays (left/right symmetry matters).
#     - Random cropping may not be suitable for small objects.
# When used appropriately, data augmentation is one of your best tools for effective training of neural networks for image processing tasks.

# %% [markdown]
# #### Viewing the Data Augmentations for MNIST

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# 1) Build your augmentation pipeline with an explicit InputLayer
data_augmentation = models.Sequential([
    InputLayer(input_shape=(28,28,1)),
    RandomRotation(0.1,    fill_mode="nearest"),  # up to ±36°
    RandomZoom(0.1,        fill_mode="nearest"),
    RandomTranslation(0.1, 0.1, fill_mode="nearest"),
    RandomContrast(0.1),
], name="data_augmentation")

# 2) Grab one example and cast to float32
#    (this assumes x_train in [0,1]; if yours is 0–255, divide by 255.0 first)
single_image = X_train[0]                     # shape (28,28,1) or (28,28)
single_image = np.expand_dims(single_image, -1) if single_image.ndim==2 else single_image
single_image = single_image.astype("float32")
label = np.argmax(y_train[0])

# 3) Make a batch of N copies in one go
N = 8
batch = tf.repeat(single_image[None,...], repeats=N, axis=0)  # shape (N,28,28,1)

# 4) Augment + clip
augmented_batch = data_augmentation(batch, training=True)
augmented_batch = tf.clip_by_value(augmented_batch, 0.0, 1.0)

# 5) Plot 3×3 grid: original + 8 variants
plt.figure(figsize=(10,10))

# original in top-left
plt.subplot(3,3,1)
plt.imshow(single_image[...,0], cmap="gray")
plt.title(f"Original: {label}")
plt.axis("off")

# then the augmented ones
for i in range(N):
    plt.subplot(3,3,i+2)
    plt.imshow(augmented_batch[i,...,0].numpy(), cmap="gray")
    plt.axis("off")

plt.suptitle("MNIST: Original + 8 Augmented Variants")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Appendix Three: Using TensorBoard
#
#
# TensorBoard is an interactive visualization tool which logs training progress and lets you inspect loss, accuracy, learning rate, and many other statistics over time.
#
# If you are only interested in loss and accuracy, this is a bit of overkill, but definitely worth checking out.
#
# You set it up using a callback, as we described in last week's coding notebook.

# %%
'''
# Define log directory (unique per run)
log_dir = os.path.join("logs", "fit", time.strftime("run_%Y%m%d-%H%M%S"))
tensorboard_cb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Optional: add EarlyStopping or others if desired
callbacks_list = [tensorboard_cb]

# Start timing
start = time.time()

# Training parameters
n_epochs = 100
batch_size = 128

# Build and train the model
base_model = build_model(lr=1e-4)
history_base = base_model.fit(
    X_train, y_train,
    epochs=n_epochs,
    batch_size=batch_size,
    validation_split=0.2,
    callbacks=callbacks_list,
    verbose=0
)

# End timing
end = time.time()
print(f"\nTotal Execution Time: {format_time(end-start)}")
'''
None

# %% [markdown]
# Once you've run this, you can visualize the training progress by running the following command in your terminal (from the root of your project):
#
# ```bash
# tensorboard --logdir=logs/fit
# ```
#
# Then open your browser and go to [http://localhost:6006](http://localhost:6006).
